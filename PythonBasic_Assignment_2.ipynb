# %%
1.What are the two values of the Boolean data type? How do you write them? 

==>

The Boolean data type in Python has two values: True and False. They represent the truth values of logic and are used to 
evaluate conditions and control the flow of a program.

# %%
2. What are the three different types of Boolean operators?

==>

AND: 
    The and operator returns True if both operands (values or expressions) on its left and right are True. 
    Otherwise, it returns False. In other words, for the and operator to yield True, all the operands must be True.
    
OR: 
    The or operator returns True if at least one of the operands on its left or right is True. 
    It returns False only if both operands are False.
    
NOT: 
    The not operator is a unary operator that negates the Boolean value of its operand. 
    If the operand is True, not will return False, and if the operand is False, not will return True.

# %%
3. Make a list of each Boolean operators truth tables (i.e. every possible combination of Boolean 
  values for the operator and what it evaluate ).

==>

AND Operator (Logical Conjunction):

Operand 1   Operand 2   Result

False       False       False
False       True        False
True        False       False
True        True        True

OR Operator (Logical Disjunction):

Operand 1   Operand 2   Result

False       False       False
False       True        True
True        False       True
True        True        True

NOT Operator (Logical Negation):

Operand     Result

False       True
True        False

# %%
4. What are the values of the following expressions?
(5 > 4) and (3 == 5)
not (5 > 4)
(5 > 4) or (3 == 5)
not ((5 > 4) or (3 == 5))
(True and True) and (True == False)
(not False) or (not True)

==>

(5 > 4) and (3 == 5)

(5 > 4) evaluates to True because 5 is greater than 4.
(3 == 5) evaluates to False because 3 is not equal to 5.
True and False evaluates to False because both conditions must be True for the and operator to return True.
Result: False
not (5 > 4)

(5 > 4) evaluates to True.
not True evaluates to False because not negates the Boolean value.
Result: False
(5 > 4) or (3 == 5)

(5 > 4) evaluates to True.
(3 == 5) evaluates to False.
True or False evaluates to True because at least one condition is True for the or operator.
Result: True
not ((5 > 4) or (3 == 5))

(5 > 4) evaluates to True.
(3 == 5) evaluates to False.
(True or False) evaluates to True.
not True evaluates to False.
Result: False
(True and True) and (True == False)

True and True evaluates to True because both conditions are True.
True == False evaluates to False because True is not equal to False.
True and False evaluates to False because both conditions must be True for the and operator.
Result: False
(not False) or (not True)

not False evaluates to True.
not True evaluates to False.
True or False evaluates to True because at least one condition is True for the or operator.
Result: True

# %%
5. What are the six comparison operators?

==>

The six comparison operators in Python are used to compare two values or expressions and return a Boolean
result (True or False) based on the comparison. Here are the six comparison operators:

Equal to: ==
Checks if two values or expressions are equal.

Not equal to: !=
Checks if two values or expressions are not equal.

Greater than: >
Checks if the value or expression on the left is greater than the one on the right.

Less than: <
Checks if the value or expression on the left is less than the one on the right.

Greater than or equal to: >=
Checks if the value or expression on the left is greater than or equal to the one on the right.

Less than or equal to: <=
Checks if the value or expression on the left is less than or equal to the one on the right.

# %%
6. How do you tell the difference between the equal to and assignment operators?Describe a
condition and when you would use one.

==>

Equal to Operator ==:

The equal to operator is a comparison operator used to check whether two values or expressions are equal.
It returns a Boolean value (True or False) based on the comparison.
Example: x == y checks if the value of x is equal to the value of y.

Assignment Operator =:
    
The assignment operator is used to assign a value to a variable.
It takes the value on its right and stores it in the variable on its left.
Example: x = 10 assigns the value 10 to the variable x.
    
You would use the equal to operator (==) when you need to compare values or expressions to check for equality.
This is often used in conditional statements (if, elif, else) or when evaluating conditions in loops and functions.
    
You would use the assignment operator (=) when you want to assign a value to a variable. 
This is common when initializing variables or updating their values during the program's execution.

# %%
7. Identify the three blocks in this code:
spam = 0
if spam == 10:
print('eggs')
if spam > 5:
print('bacon')
else:
print('ham')
print('spam';)
print('spam')

==>

Block 1:

This block consists of an if statement.
The condition spam == 10 is checked, but since spam is assigned the value 0, the condition evaluates to False, 
and the indented code (print('eggs')) inside the block is not executed.

Block 2:
This block also consists of an if statement.
The condition spam > 5 is checked, but since spam has the value 0, the condition evaluates to False, 
and the indented code (print('bacon')) inside the block is not executed.

Block 3:
This block consists of an else statement.
Since the previous if statement in Block 2 evaluates to False, the code inside the else block is executed.
It prints 'ham', 'spam', and 'spam' because they are not indented and therefore not part of the previous if or else statements.

# %%
8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints
Greetings! if anything else is stored in spam.

==>

spam = input('Enter no')

if spam == 1:
    print("Hello")
elif spam == 2:
    print("Howdy")
else:
    print("Greetings!")

# %%
9.If your programme is stuck in an endless loop, what keys you’ll press?

==>

Ctrl + C: This is the most common and universal way to interrupt a running program and stop it on most platforms. 
    Pressing Ctrl and C keys simultaneously will send an interrupt signal to the program, causing it to terminate.

Ctrl + Break: On Windows systems, pressing Ctrl and Break keys together can also be used to interrupt a program similar 
    to Ctrl + C.

Ctrl + Z: On some systems, like Unix-based systems (Linux and macOS), pressing Ctrl and Z keys can suspend the program.
    However, this may not stop the program immediately, and you might need to use other commands like kill or killall to
    terminate the program completely.

# %%
10. How can you tell the difference between break and continue?

==>

 break is used to exit the loop entirely when a condition is met, 
 while continue is used to skip the current iteration and continue with the next iteration of the loop.

# %%
11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?

==>

range(10):

This expression generates a sequence of numbers from 0 to 9 (10 numbers in total).
The range() function by default starts from 0 and stops just before the specified end value (exclusive). In this case,
the end value is 10, so the sequence includes numbers 0, 1, 2, ..., 9.
It uses the default step value of 1, which means the numbers in the sequence are incremented by 1 at each step.

range(0, 10):

This expression also generates a sequence of numbers from 0 to 9 (10 numbers in total).
The range() function starts from the specified start value, which is 0, and stops just before the specified end value (exclusive), which is 10.
Like the previous case, it uses the default step value of 1.

range(0, 10, 1):

This expression is equivalent to the previous two examples.
It explicitly specifies the start value as 0, the end value as 10, and the step value as 1.
Since the step value is 1, it increments the numbers in the sequence by 1 at each step.

# %%
12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent
program that prints the numbers 1 to 10 using a while loop.

==>

# Using a for loop
for i in range(1, 11):
    print(i)

    
# Using a while loop
i = 1
while i <= 10:
    print(i)
    i += 1

# %%
13. If you had a function named bacon() inside a module named spam, how would you call it after
importing spam?

==>

If you have a function named bacon() inside a module named spam, and you want to call that function 
after importing the spam module, you can use the dot notation to access the function. Here is how you would do it:

import spam
spam.bacon()
